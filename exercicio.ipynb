# %% [markdown]
# # Exercício Hora Um
#
# - DataSet escolhido ranqueia os 100 jogos mais populares da plataforma Steam no mês de Julho de 2024
# - A popularidade dos jogos é estimada de acordo com o pico de jogadores simultâneos no período de 24 horas

# %% [markdown]
# ## Importação do Pandas

# %%
import pandas as pd

# %% [markdown]
# ## Importando os dados

# %%
url = "dataset/top_100_steam_games.csv"

pd.read_csv(url)
# Out:
#      Rank                                         Image Link  \
# 0     1.0  https://shared.cloudflare.steamstatic.com/stor...
# 1     2.0  https://shared.cloudflare.steamstatic.com/stor...
# 2     3.0  https://shared.cloudflare.steamstatic.com/stor...
# 3     4.0  https://shared.cloudflare.steamstatic.com/stor...
# 4     5.0  https://shared.cloudflare.steamstatic.com/stor...
# ..    ...                                                ...
# 95   96.0  https://shared.cloudflare.steamstatic.com/stor...
# 96   97.0  https://shared.cloudflare.steamstatic.com/stor...
# 97   98.0  https://shared.cloudflare.steamstatic.com/stor...
# 98   99.0  https://shared.cloudflare.steamstatic.com/stor...
# 99  100.0  https://shared.cloudflare.steamstatic.com/stor...
#
#                     Title    Current   24h Peak All-Time Peak  \
# 0        Counter-Strike 2  1,015,721  1,276,702     1,818,773
# 1                  Dota 2    702,487    805,624     1,295,114
# ...

# %% [markdown]
# ## Criando o DataFrame

# %%
dados = pd.read_csv(url)
dados
# Out:
#      Rank                                         Image Link  \
# 0     1.0  https://shared.cloudflare.steamstatic.com/stor...
# 1     2.0  https://shared.cloudflare.steamstatic.com/stor...
# 2     3.0  https://shared.cloudflare.steamstatic.com/stor...
# 3     4.0  https://shared.cloudflare.steamstatic.com/stor...
# 4     5.0  https://shared.cloudflare.steamstatic.com/stor...
# ..    ...                                                ...
# 95   96.0  https://shared.cloudflare.steamstatic.com/stor...
# 96   97.0  https://shared.cloudflare.steamstatic.com/stor...
# 97   98.0  https://shared.cloudflare.steamstatic.com/stor...
# 98   99.0  https://shared.cloudflare.steamstatic.com/stor...
# 99  100.0  https://shared.cloudflare.steamstatic.com/stor...
#
#                     Title    Current   24h Peak All-Time Peak  \
# 0        Counter-Strike 2  1,015,721  1,276,702     1,818,773
# 1                  Dota 2    702,487    805,624     1,295,114
# ...

# %% [markdown]
# ## Exibindo os 5 primeiros

# %%
dados.head()
# Out:
#    Rank                                         Image Link  \
# 0   1.0  https://shared.cloudflare.steamstatic.com/stor...
# 1   2.0  https://shared.cloudflare.steamstatic.com/stor...
# 2   3.0  https://shared.cloudflare.steamstatic.com/stor...
# 3   4.0  https://shared.cloudflare.steamstatic.com/stor...
# 4   5.0  https://shared.cloudflare.steamstatic.com/stor...
#
#                  Title    Current   24h Peak All-Time Peak  \
# 0     Counter-Strike 2  1,015,721  1,276,702     1,818,773
# 1               Dota 2    702,487    805,624     1,295,114
# 2               Banana    409,758    428,540       917,272
# 3  PUBG: BATTLEGROUNDS    371,000    688,475     3,257,248
# 4           ELDEN RING    294,359    319,707       953,426
#
#                                     Genre
# 0                    First-person Shooter
# 1  MOBA (Multiplayer Online Battle Arena)
# 2                                 Unknown
# 3                           Battle Royale
# ...

# %% [markdown]
# ## Exibindo os 20 primeiros

# %%
dados.head(20)
# Out:
#     Rank                                         Image Link  \
# 0    1.0  https://shared.cloudflare.steamstatic.com/stor...
# 1    2.0  https://shared.cloudflare.steamstatic.com/stor...
# 2    3.0  https://shared.cloudflare.steamstatic.com/stor...
# 3    4.0  https://shared.cloudflare.steamstatic.com/stor...
# 4    5.0  https://shared.cloudflare.steamstatic.com/stor...
# 5    6.0  https://shared.cloudflare.steamstatic.com/stor...
# 6    7.0  https://shared.cloudflare.steamstatic.com/stor...
# 7    8.0  https://encrypted-tbn0.gstatic.com/images?q=tb...
# 8    9.0  https://shared.cloudflare.steamstatic.com/stor...
# 9   10.0  https://shared.cloudflare.steamstatic.com/stor...
# 10  11.0  https://shared.cloudflare.steamstatic.com/stor...
# 11  12.0  https://shared.cloudflare.steamstatic.com/stor...
# 12  13.0  https://shared.cloudflare.steamstatic.com/stor...
# 13  14.0  https://shared.cloudflare.steamstatic.com/stor...
# 14  15.0  https://shared.cloudflare.steamstatic.com/stor...
# ...

# %% [markdown]
# ## Exibindo os 5 últimos

# %%
dados.tail()
# Out:
#      Rank                                         Image Link  \
# 95   96.0  https://shared.cloudflare.steamstatic.com/stor...
# 96   97.0  https://shared.cloudflare.steamstatic.com/stor...
# 97   98.0  https://shared.cloudflare.steamstatic.com/stor...
# 98   99.0  https://shared.cloudflare.steamstatic.com/stor...
# 99  100.0  https://shared.cloudflare.steamstatic.com/stor...
#
#                     Title Current 24h Peak All-Time Peak                 Genre
# 95               Soundpad  16,028   17,064        21,920   Simulation / Tycoon
# 96  Supermarket Simulator  15,817   15,875        51,363  Vampire / Open world
# 97               V Rising  15,803   16,275       150,645      Tactical Shooter
# 98                  Squad  15,729   19,288        35,151        Grand Strategy
# 99             Victoria 3  15,609   17,598        70,100               Unknown

# %% [markdown]
# ## Exibindo os 20 últimos

# %%
dados.tail(20)
# Out:
#      Rank                                         Image Link  \
# 80   81.0  https://shared.cloudflare.steamstatic.com/stor...
# 81   82.0  https://shared.cloudflare.steamstatic.com/stor...
# 82   83.0  https://shared.cloudflare.steamstatic.com/stor...
# 83   84.0  https://shared.cloudflare.steamstatic.com/stor...
# 84   85.0  https://shared.cloudflare.steamstatic.com/stor...
# 85   86.0  https://shared.cloudflare.steamstatic.com/stor...
# 86   87.0  https://shared.cloudflare.steamstatic.com/stor...
# 87   88.0  https://shared.cloudflare.steamstatic.com/stor...
# 88   89.0  https://shared.cloudflare.steamstatic.com/stor...
# 89   90.0  https://shared.cloudflare.steamstatic.com/stor...
# 90   91.0  https://shared.cloudflare.steamstatic.com/stor...
# 91   92.0  https://shared.cloudflare.steamstatic.com/stor...
# 92   93.0  https://shared.cloudflare.steamstatic.com/stor...
# 93   94.0  https://shared.cloudflare.steamstatic.com/stor...
# ...
